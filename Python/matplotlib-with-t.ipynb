# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/iris/Iris.csv
# /kaggle/input/iris/database.sqlite

# %%
df=pd.read_csv('/kaggle/input/iris/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
#line plot basic plotting

year = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
qty = [10, 15, 13, 17, 20, 18, 22, 24, 26]
 
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.plot(year,qty,marker='*', linestyle='-', color='r', label='Value over Years')
# title of the plot
plt.title("A line plot with fictional data")
# add labels to the axis
plt.xlabel("Years")
plt.ylabel('Sales of products (in thousands)')
# grid
# legend
plt.legend()
plt.show()

# %%
year = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
qty = [10, 15, 13, 17, 20, 18, 22, 24, 26]
 
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.bar(year,qty, color='#40e0d0',width = 0.3, label='Value over Years')
# title of the plot
plt.title("A scatter plot with fictional data")
# add labels to the axis
plt.xlabel("Years")
plt.ylabel('Sales of products (in thousands)')
# grid
# legend
plt.legend()
plt.show()

# %%
year = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
qty = [10, 15, 13, 17, 20, 18, 22, 24, 26]
 
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.bar(year,qty, color='#40e0d0', label='Value over Years')
# title of the plot
plt.title("A scatter plot with fictional data")
# add labels to the axis
plt.xlabel("Years")
plt.ylabel('Sales of products (in thousands)')
# grid
# legend
plt.legend()
plt.show()

# %%
year = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
qty = [10, 15, 13, 17, 20, 18, 22, 24, 26]
 
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.bar(year,qty, color='#40e0d0',width = 0.3, label='Value over Years')
# title of the plot
plt.title("A scatter plot with fictional data")
# add labels to the axis
plt.xlabel("Years")
plt.ylabel('Sales of products (in thousands)')
# grid
# legend
plt.legend()
plt.show()

# %%
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.hist(df['Species'], color='#40e0d0',width = 0.3, label='Frequency of species')
# title of the plot
plt.title("Histogram of the count of species")
# add labels to the axis
plt.xlabel("Species name")
plt.ylabel('Count of species')
# grid
# legend
plt.legend()
plt.show()

# %%
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.scatter('SepalLengthCm','SepalWidthCm',marker='o', s=35, linestyle='-',data=df)
# title of the plot
plt.title("A scatter plot with iris data", fontsize=14,color='Blue' )
# add labels to the axis
plt.xlabel("SepalLengthCm", fontsize=14)
plt.ylabel('SepalWidthCm', fontsize=14)
# grid
# legend
plt.legend(loc="upper left",title="Sepal width and length", title_fontsize=12)
plt.show()

# %%
data_plot_group=df.groupby('Species').agg({'SepalLengthCm':'mean','SepalWidthCm':'mean',
                                           'PetalLengthCm':'mean','PetalWidthCm':'mean'}).reset_index()
data_plot_group
# Out:
#            Species  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      Iris-setosa          5.006         3.418          1.464         0.244
# 1  Iris-versicolor          5.936         2.770          4.260         1.326
# 2   Iris-virginica          6.588         2.974          5.552         2.026

# %%
plt.style.use('_mpl-gallery')
 
# code to plot 
plt.figure(figsize=(10,6))
plt.bar(data_plot_group.Species,data_plot_group.SepalLengthCm, color='#40e0d0',width = 0.3,label='Species')
# title of the plot
plt.title("A bar plot with average Sepal Length per species",fontsize=16,color='Green')
# add labels to the axis
plt.xlabel("Species",fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.ylabel('Average sepal length',fontsize=12)
plt.yticks(fontsize=12)
# grid
# legend
plt.legend()
plt.show()

# %% [markdown]
# # seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='SepalLengthCm',y='SepalWidthCm', hue='Species')
# title of the plot
plt.title("A seaborn scatterplot with average Sepal Length per species",fontsize=16,color='#61d290')
# add labels to the axis
plt.xlabel("SepalLengthCm",fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.ylabel('SepalWidthCm',fontsize=12)
plt.yticks(fontsize=12)
# grid
# legend
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x='SepalLengthCm',y='SepalWidthCm', hue='Species',palette='deep')
#scatterplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, palette=None, hue_order=None, 
#hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, legend="auto", ax=None, **kwargs)
# title of the plot
plt.title("A seaborn scatterplot with average Sepal Length per species",fontsize=16,color='#61d290')
# add labels to the axis
plt.xlabel("SepalLengthCm",fontsize=12)
plt.xticks(rotation=0, fontsize=10)
plt.ylabel('SepalWidthCm',fontsize=12)
plt.yticks(fontsize=12)
# grid
# legend
plt.legend()
plt.show()

# %%
# pair plot
import warnings  
# Settings the warnings to be ignored 
warnings.filterwarnings('ignore')
 
plt.figure(figsize=(10,6))
sns.pairplot(df)
plt.show()

# %%
data={
'year' : [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
'qty' : [10, 15, 13, 17, 20, 18, 22, 24, 26]
}

# %%
df2=pd.DataFrame(data)
df2
# Out:
#    year  qty
# 0  2015   10
# 1  2016   15
# 2  2017   13
# 3  2018   17
# 4  2019   20
# 5  2020   18
# 6  2021   22
# 7  2022   24
# 8  2023   26

# %%
# code to plot 
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10,6))
# Plot the responses for different events and regions
sns.lineplot(x="qty", y="year",marker='s',markerfacecolor='orange',markersize=13,data=df2)
# title of the plot
plt.title("A line plot with fictional data")
# add labels to the axis
plt.xlabel("Years")
plt.ylabel('Sales of products (in thousands)')
plt.legend()
plt.show()
