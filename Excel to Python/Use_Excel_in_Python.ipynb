# %% [markdown]
# <a href="https://colab.research.google.com/github/dizstarry/Data_Portfolio/blob/main/Use_Excel_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Use Excel File in Python**

# %% [markdown]
# **Data**
# https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

# %%
import pandas
data = pandas.read_excel('bank.xlsx')

# %%
data
# Out:
#     age            job   marital  education default  balance housing loan  \
# 0    30     unemployed   married    primary      no     1787      no   no
# 1    33       services   married  secondary      no     4789     yes  yes
# 2    35     management    single   tertiary      no     1350     yes   no
# 3    30     management   married   tertiary      no     1476     yes  yes
# 4    59    blue-collar   married  secondary      no        0     yes   no
# 5    35     management    single   tertiary      no      747      no   no
# 6    36  self-employed   married   tertiary      no      307     yes   no
# 7    39     technician   married  secondary      no      147     yes   no
# 8    41   entrepreneur   married   tertiary      no      221     yes   no
# 9    43       services   married    primary      no      -88     yes  yes
# 10   39       services   married  secondary      no     9374     yes   no
# 11   43         admin.   married  secondary      no      264     yes   no
# ...

# %%
data_dictionary = data.to_dict()

# %%
data_dictionary
# Out:
# {'age': {0: 30,
#   1: 33,
#   2: 35,
#   3: 30,
#   4: 59,
#   5: 35,
#   6: 36,
#   7: 39,
#   8: 41,
#   9: 43,
#   10: 39,
#   11: 43,
#   12: 36,
#   13: 20,
#   14: 31,
#   15: 40,
#   16: 56,
#   17: 37,
#   18: 25,
#   19: 31,
#   20: 38,
#   21: 42,
#   22: 44,
#   23: 44,
#   24: 26,
#   25: 41,
#   26: 55,
#   27: 67},
#  'job': {0: 'unemployed',
#   1: 'services',
#   2: 'management',
#   3: 'management',
#   4: 'blue-collar',
#   5: 'management',
#   6: 'self-employed',
#   7: 'technician',
#   8: 'entrepreneur',
#   9: 'services',
#   10: 'services',
#   11: 'admin.',
#   12: 'technician',
#   13: 'student',
#   14: 'blue-collar',
#   15: 'management',
#   16: 'technician',
#   17: 'admin.',
#   18: 'blue-collar',
#   19: 'services',
#   20: 'management',
#   21: 'management',
#   22: 'services',
#   23: 'entrepreneur',
#   24: 'housemaid',
#   25: 'management',
#   26: 'blue-collar',
#   27: 'retired'},
#  'marital': {0: 'married',
#   1: 'married',
#   2: 'single',
# ...

# %%
data_dictionary = data.to_dict('records')

# %%
data_dictionary
# Out:
# [{'age': 30,
#   'job': 'unemployed',
#   'marital': 'married',
#   'education': 'primary',
#   'default': 'no',
#   'balance': 1787,
#   'housing': 'no',
#   'loan': 'no',
#   'contact': 'cellular',
#   'day': 19,
#   'month': 'oct',
#   'duration': 79,
#   'campaign': 1,
#   'pdays': -1,
#   'previous': 0,
#   'poutcome': 'unknown',
#   'y': 'no'},
#  {'age': 33,
#   'job': 'services',
#   'marital': 'married',
#   'education': 'secondary',
#   'default': 'no',
#   'balance': 4789,
#   'housing': 'yes',
#   'loan': 'yes',
#   'contact': 'cellular',
#   'day': 11,
#   'month': 'may',
#   'duration': 220,
#   'campaign': 1,
#   'pdays': 339,
#   'previous': 4,
#   'poutcome': 'failure',
#   'y': 'no'},
#  {'age': 35,
#   'job': 'management',
#   'marital': 'single',
#   'education': 'tertiary',
#   'default': 'no',
#   'balance': 1350,
#   'housing': 'yes',
#   'loan': 'no',
#   'contact': 'cellular',
#   'day': 16,
#   'month': 'apr',
#   'duration': 185,
#   'campaign': 1,
# ...

# %% [markdown]
# **01. Manipulate Excel File With Python**

# %%
data_dictionary[0]
# Out:
# {'age': 30,
#  'job': 'unemployed',
#  'marital': 'married',
#  'education': 'primary',
#  'default': 'no',
#  'balance': 1787,
#  'housing': 'no',
#  'loan': 'no',
#  'contact': 'cellular',
#  'day': 19,
#  'month': 'oct',
#  'duration': 79,
#  'campaign': 1,
#  'pdays': -1,
#  'previous': 0,
#  'poutcome': 'unknown',
#  'y': 'no'}

# %%
data_dictionary[1]
# Out:
# {'age': 33,
#  'job': 'services',
#  'marital': 'married',
#  'education': 'secondary',
#  'default': 'no',
#  'balance': 4789,
#  'housing': 'yes',
#  'loan': 'yes',
#  'contact': 'cellular',
#  'day': 11,
#  'month': 'may',
#  'duration': 220,
#  'campaign': 1,
#  'pdays': 339,
#  'previous': 4,
#  'poutcome': 'failure',
#  'y': 'no'}

# %%
data_dictionary[0].keys()
# Out:
# dict_keys(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y'])

# %%
list(data_dictionary[0].keys())
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'balance',
#  'housing',
#  'loan',
#  'contact',
#  'day',
#  'month',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'y']

# %%
data_dictionary[0].values()
# Out:
# dict_values([30, 'unemployed', 'married', 'primary', 'no', 1787, 'no', 'no', 'cellular', 19, 'oct', 79, 1, -1, 0, 'unknown', 'no'])

# %%
list(data_dictionary[0].values())
# Out:
# [30,
#  'unemployed',
#  'married',
#  'primary',
#  'no',
#  1787,
#  'no',
#  'no',
#  'cellular',
#  19,
#  'oct',
#  79,
#  1,
#  -1,
#  0,
#  'unknown',
#  'no']

# %% [markdown]
# **Build Dictionaries with Python**

# %%
person = {'age' : 30}
person
# Out:
# {'age': 30}

# %%
person = dict(age = 30)
person
# Out:
# {'age': 30}

# %%
apple = dict(color = 'red', WeightInPounds = 1)
apple
# Out:
# {'color': 'red', 'WeightInPounds': 1}
